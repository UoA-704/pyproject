# %% [markdown]
# ### Understanding Player Behavior Through Gameplay Time, Ratings, and Sentiment
#
# **Team:** Group 11
#
# - Yicong Li  - 691671170
# - Yuxuan Chi - 669019311
# - Yiyi Zhang - 871813506
# - Yijie Yang - 916572596

# %% [markdown]
# # ---------------------------------------------------------
# ### Introduction
# In this project, we chose the **Video Game Industry** as the theme for data cleaning and integration.
# The reasons for selecting this topic are as follows:
#
# - The video game industry is one of the fastest-growing global cultural and technological sectors.
#   Its data—such as sales volume, player preferences, and game genres—shows clear trends and strong research value.
#
# - The data sources are abundant and easy to access, making them suitable for cross-platform data integration.
#   For example, large platforms such as **Kaggle** and **Steam** provide extensive public game information with clear patterns in ratings, player behaviour, and game types.
#
# - Game datasets often contain issues such as missing values, inconsistent formats, duplicate entries, mixed categories, and     natural-language challenges within player reviews. This makes them highly suitable for practicing comprehensive data cleaning   and preprocessing.
#
# Therefore, in this project, we use two datasets provided by **Kaggle**, and through cleaning, field alignment, and merging processes, we construct a final **analysis-ready dataset** for our research tasks.
#
# # ---------------------------------------------------------

# %% [markdown]
# ### Task 1

# %% [markdown]
# # ---------------------------------------------------------
# Wrangling Steps — Data Import Stage
#
# This section of the code performs the following tasks:
# 1. Import the required Python libraries for later analysis (e.g., pandas, numpy)
# 2. Specify the file paths
# 3. Load the two external datasets (vgsales.csv / hltb.jsonlines)
# 4. Apply dataset-specific cleaning procedures (e.g., handling NA, missing values, removing unnecessary columns) to prepare them for analysis
# 5. Merge both datasets into the final combined dataset, which includes the following columns:
#    gameName, genre, reviewScore, playTime
# # ---------------------------------------------------------

# %%
## loading needed packages
import pandas as pd
import numpy as np
import re

# %% [markdown]
# **Task 1: dataset 1 (vgslaes.csv) - load & clean**

# %%
## data path
data_path = './dataset/'

## mandatory dataset （dataset 1）
## This dataset we want to get game name and genre for further analysis
vgsales = pd.read_csv(data_path + "vgsales.csv") 
vgsales
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %% [markdown]
# - Import only the required columns (game name, genre)

# %%
vgsales = vgsales[["Name", "Genre"]].copy()
vgsales_unique = vgsales.drop_duplicates(subset=["Name"], keep="first").reset_index(drop=True)
vgsales_unique
# Out:
#                                                     Name         Genre
# 0                                             Wii Sports        Sports
# 1                                      Super Mario Bros.      Platform
# 2                                         Mario Kart Wii        Racing
# 3                                      Wii Sports Resort        Sports
# 4                               Pokemon Red/Pokemon Blue  Role-Playing
# ...                                                  ...           ...
# 11488  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...        Action
# 11489  Eiyuu Densetsu: Sora no Kiseki Material Collec...  Role-Playing
# 11490                                           Plushees    Simulation
# 11491                 Woody Woodpecker in Crazy Castle 5      Platform
# 11492                                         Know How 2        Puzzle
#
# [11493 rows x 2 columns]

# %% [markdown]
# Task 1: dataset 2 (hltb.jsonlines) - load & clean

# %%
## dataset 2 (hltb.jsonlines)
hltb = pd.read_json(data_path + "hltb.jsonlines", lines=True)
hltb.head()
# Out:
#                                Name  \
# 0                     Borderlands 3
# 1                       Dying Light
# 2       Middle-Earth: Shadow of War
# 3  Counter-Strike: Global Offensive
# 4               Grand Theft Auto IV
#
#                                                Stats  steam_app_id  \
# 0  {'Additional Content': {'Moxxi's Heist of the ...      397540.0
# 1  {'Additional Content': {'The Following': {'Pol...      239140.0
# 2  {'Additional Content': {'Blade of Galadriel': ...      356190.0
# 3  {'Multi-Player': {'Co-Op': {'Polled': '34', 'A...         730.0
# 4  {'Additional Content': {'The Lost and Damned':...        5152.0
#
#   Release_date                                          Genres  Review_score
# 0   2019-09-13                   First-Person, Action, Shooter            76
# 1   2015-01-27  Action, Adventure, Open World, Survival Horror            78
# 2   2017-10-10                               Action, Adventure            76
# 3   2012-08-21                           First-Person, Shooter            74
# 4   2008-04-29          Third-Person, Action, Sandbox, Shooter            82

# %% [markdown]
# - Extracting and Normalizing Platform Playtime Data (define a function)

# %%
## the 'stats' column contains the average playtime for each platform,
## we need to extract the playtime values for every platform as reference data 
## for further analysis.
## The code below keeps only entries where 'platform' data is non-empty;
## rows with empty or zero-value platform data will be filtered out.

def normalize_stats(stats):
    # If the value is not a dict (e.g., NaN / None) → return an empty dict
    if not isinstance(stats, dict):
        return {}
    
    # Case 1: 'Platform' wraps another level:
    # {'Platform': {'PC': {...}, 'PS4': {...}}}
    if "Platform" in stats:
        inner = stats["Platform"]
        return inner if isinstance(inner, dict) else {}
    
    # Case 2: No 'Platform' key — already in the format:
    # {'PC': {...}, 'PS4': {...}}
    return stats

hltb["Stats"] = hltb["Stats"].apply(normalize_stats)
mask = hltb["Stats"].apply(lambda x: isinstance(x, dict) and len(x) > 0)
hltb = hltb[mask].reset_index(drop=True)

## check how the stats looks like
hltb['Stats'][0]
# Out:
# {'Google Stadia': {'Polled': '12',
#   'Main': '28h 40m',
#   'Main +': '65h 40m',
#   '100%': '133h 1m',
#   'Fastest': '25h',
#   'Slowest': '158h'},
#  'PC': {'Polled': '926',
#   'Main': '22h 57m',
#   'Main +': '46h 14m',
#   '100%': '83h 11m',
#   'Fastest': '11h 6m',
#   'Slowest': '498h'},
#  'PlayStation 4': {'Polled': '248',
#   'Main': '23h 52m',
#   'Main +': '46h 5m',
#   '100%': '65h 39m',
#   'Fastest': '11h 17m',
#   'Slowest': '250h'},
#  'PlayStation 5': {'Polled': '50',
#   'Main': '25h 32m',
#   'Main +': '46h 18m',
#   '100%': '61h 13m',
#   'Fastest': '17h 28m',
#   'Slowest': '113h'},
#  'Xbox One': {'Polled': '116',
#   'Main': '23h 44m',
#   'Main +': '51h 58m',
#   '100%': '73h 22m',
#   'Fastest': '12h 3m',
#   'Slowest': '413h'},
#  'Xbox Series X/S': {'Polled': '28',
#   'Main': '22h 47m',
#   'Main +': '56h 48m',
#   '100%': '124h 1m',
#   'Fastest': '14h 12m',
#   'Slowest': '172h'}}

# %% [markdown]
# - Defining the Target Platforms (list)

# %%
## We extract the list of platform names involved in our dataset 
## (these correspond to the platform-specific average playtime values)

target_platforms = [
    "PC",
    "PlayStation 2",
    "PlayStation 3",
    "PlayStation 4",
    "PlayStation 5",
    "Xbox One",
    "Xbox 360",
    "Xbox Series X/S",
    "Super Nintendo",
    "Wii",
    "Wii U"
]

# %% [markdown]
# - Converting Playtime Strings into Numeric Hours (function)

# %%
### Convert extracted playtime strings into numeric hour values
### e.g. original value "12h 30m"  →  converted to 12.5
### e.g. original value "None"     →  converted to NaN
### The goal is to unify formatting and make later calculations easier.

def parse_hour_string(s):
    if not isinstance(s, str):
        return np.nan
    
    h = re.search(r"(\d+)h", s)
    m = re.search(r"(\d+)m", s)

    hours = int(h.group(1)) if h else 0
    mins = int(m.group(1)) if m else 0
    
    return round(hours + mins/60, 2)

# %% [markdown]
# - Extracting Main Story Playtime for Each Platform

# %%
## From the Stats column, extract the “Main” (main story playtime) value 
## for each platform in target_platforms. 
## The extracted playtime strings will then be converted into standardized 
## numeric hour values for analysis.

def extract_main_plus(stats):
    result = {}
    for p in target_platforms:
        if p in stats and isinstance(stats[p], dict):
            main_plus = stats[p].get("Main")
            result[p] = parse_hour_string(main_plus)
        else:
            result[p] = np.nan
    return result

platform_df = hltb["Stats"].apply(extract_main_plus).apply(pd.Series)

# %% [markdown]
# - Merging Cleaned Platform Playtime Data Back Into the Main Dataset

# %%
## Merge the cleaned platform-level playtime data (platform_df)
## back into the original hltb dataset to construct the final dataset.
## Then remove the original Stats column, since it is no longer needed.

hltb_final = pd.concat([hltb, platform_df], axis=1)
del hltb_final['Stats']

# %%
## check how our dataset looks like now !!!
hltb_final
# Out:
#                                    Name  steam_app_id Release_date  \
# 0                         Borderlands 3      397540.0   2019-09-13
# 1                           Dying Light      239140.0   2015-01-27
# 2           Middle-Earth: Shadow of War      356190.0   2017-10-10
# 3      Counter-Strike: Global Offensive         730.0   2012-08-21
# 4                   Grand Theft Auto IV        5152.0   2008-04-29
# ...                                 ...           ...          ...
# 35702                          PlatONIR      882070.0   2018-07-04
# 35703                       Life Beetle      527480.0   2017-04-18
# 35704          Apocalypse: Party's Over      368800.0   2016-05-30
# 35705                           10mg :)     1425380.0   2020-10-15
# 35706                          Sinistar           NaN   1982-00-00
#
#                                                   Genres  Review_score     PC  \
# 0                          First-Person, Action, Shooter            76  22.95
# 1         Action, Adventure, Open World, Survival Horror            78  17.98
# 2                                      Action, Adventure            76  20.90
# 3                                  First-Person, Shooter            74  59.85
# 4                 Third-Person, Action, Sandbox, Shooter            82  27.13
# ...                                                  ...           ...    ...
# 35702                                           Platform            10   0.00
# 35703                                                               33   0.13
# 35704                            Side, Scrolling, Action             0   4.50
# 35705  Side, Top-Down, Real-Time, Arcade, Pinball, Pu...            78   0.25
# 35706                            Action, Arcade, Shooter            69    NaN
#
#        PlayStation 2  PlayStation 3  PlayStation 4  PlayStation 5  Xbox One  \
# 0                NaN            NaN          23.87          25.53     23.73
# 1                NaN            NaN          19.20          24.98     17.08
# 2                NaN            NaN          20.60          15.93     20.77
# 3                NaN          60.00            NaN            NaN       NaN
# 4                NaN          28.65            NaN            NaN     25.77
# ...              ...            ...            ...            ...       ...
# 35702            NaN            NaN            NaN            NaN       NaN
# 35703            NaN            NaN            NaN            NaN       NaN
# 35704            NaN            NaN            NaN            NaN       NaN
# 35705            NaN            NaN            NaN            NaN       NaN
# 35706            NaN            NaN            NaN            NaN       NaN
#
#        Xbox 360  Xbox Series X/S  Super Nintendo  Wii  Wii U
# 0           NaN            22.78             NaN  NaN    NaN
# 1           NaN            17.58             NaN  NaN    NaN
# 2           NaN            23.50             NaN  NaN    NaN
# 3           NaN              NaN             NaN  NaN    NaN
# 4         29.13            23.98             NaN  NaN    NaN
# ...         ...              ...             ...  ...    ...
# 35702       NaN              NaN             NaN  NaN    NaN
# 35703       NaN              NaN             NaN  NaN    NaN
# 35704       NaN              NaN             NaN  NaN    NaN
# 35705       NaN              NaN             NaN  NaN    NaN
# 35706       NaN              NaN             NaN  NaN    NaN
#
# [35707 rows x 16 columns]

# %% [markdown]
# - Converting Platform Columns to Numeric Values and Computing Total Playtime

# %%
# Keep only the platform columns that actually exist in the DataFrame
# (this prevents errors in case a platform name is missing).
target_platforms = [c for c in target_platforms if c in hltb_final.columns]

# Convert all platform playtime columns to numeric values
# (non-numeric values → NaN).
hltb_final[target_platforms] = hltb_final[target_platforms].apply(
    pd.to_numeric, errors="coerce"
)

# Compute total playtime by summing across all platforms
# (NaN values are automatically skipped).
hltb_final["total_play_time"] = (
    hltb_final[target_platforms].sum(axis=1, skipna=True).round(2)
)

hltb_final
# Out:
#                                    Name  steam_app_id Release_date  \
# 0                         Borderlands 3      397540.0   2019-09-13
# 1                           Dying Light      239140.0   2015-01-27
# 2           Middle-Earth: Shadow of War      356190.0   2017-10-10
# 3      Counter-Strike: Global Offensive         730.0   2012-08-21
# 4                   Grand Theft Auto IV        5152.0   2008-04-29
# ...                                 ...           ...          ...
# 35702                          PlatONIR      882070.0   2018-07-04
# 35703                       Life Beetle      527480.0   2017-04-18
# 35704          Apocalypse: Party's Over      368800.0   2016-05-30
# 35705                           10mg :)     1425380.0   2020-10-15
# 35706                          Sinistar           NaN   1982-00-00
#
#                                                   Genres  Review_score     PC  \
# 0                          First-Person, Action, Shooter            76  22.95
# 1         Action, Adventure, Open World, Survival Horror            78  17.98
# 2                                      Action, Adventure            76  20.90
# 3                                  First-Person, Shooter            74  59.85
# 4                 Third-Person, Action, Sandbox, Shooter            82  27.13
# ...                                                  ...           ...    ...
# 35702                                           Platform            10   0.00
# 35703                                                               33   0.13
# 35704                            Side, Scrolling, Action             0   4.50
# 35705  Side, Top-Down, Real-Time, Arcade, Pinball, Pu...            78   0.25
# 35706                            Action, Arcade, Shooter            69    NaN
#
#        PlayStation 2  PlayStation 3  PlayStation 4  PlayStation 5  Xbox One  \
# 0                NaN            NaN          23.87          25.53     23.73
# 1                NaN            NaN          19.20          24.98     17.08
# 2                NaN            NaN          20.60          15.93     20.77
# 3                NaN          60.00            NaN            NaN       NaN
# 4                NaN          28.65            NaN            NaN     25.77
# ...              ...            ...            ...            ...       ...
# 35702            NaN            NaN            NaN            NaN       NaN
# 35703            NaN            NaN            NaN            NaN       NaN
# 35704            NaN            NaN            NaN            NaN       NaN
# 35705            NaN            NaN            NaN            NaN       NaN
# 35706            NaN            NaN            NaN            NaN       NaN
#
#        Xbox 360  Xbox Series X/S  Super Nintendo  Wii  Wii U  total_play_time
# 0           NaN            22.78             NaN  NaN    NaN           118.86
# 1           NaN            17.58             NaN  NaN    NaN            96.82
# 2           NaN            23.50             NaN  NaN    NaN           101.70
# 3           NaN              NaN             NaN  NaN    NaN           119.85
# 4         29.13            23.98             NaN  NaN    NaN           134.66
# ...         ...              ...             ...  ...    ...              ...
# 35702       NaN              NaN             NaN  NaN    NaN             0.00
# 35703       NaN              NaN             NaN  NaN    NaN             0.13
# 35704       NaN              NaN             NaN  NaN    NaN             4.50
# 35705       NaN              NaN             NaN  NaN    NaN             0.25
# 35706       NaN              NaN             NaN  NaN    NaN             0.00
#
# [35707 rows x 17 columns]

# %% [markdown]
# Task 1: Merge the two datasets to obtain our final integrated dataset

# %%
merged_df = pd.merge(
    hltb_final,
    vgsales,
    on="Name",      
    how="inner"     
)

## drop dulplicated names
merged_df_unique = merged_df.drop_duplicates(subset=["Name"], keep="first")
merged_df_unique
# Out:
#                      Name  steam_app_id Release_date  \
# 0             Dying Light      239140.0   2015-01-27
# 3     Grand Theft Auto IV        5152.0   2008-04-29
# 6             The Witcher       20900.0   2007-10-30
# 7               Half-Life          70.0   1998-11-19
# 9               Far Cry 3      220240.0   2012-11-29
# ...                   ...           ...          ...
# 9114  Tetris Party Deluxe           NaN   2010-06-01
# 9116     Fantastic Voyage           NaN   1982-00-00
# 9117                Azada        7340.0   0000-00-00
# 9119        Tetris Worlds           NaN   2001-09-05
# 9122           Bank Heist           NaN   1983-00-00
#
#                                               Genres  Review_score     PC  \
# 0     Action, Adventure, Open World, Survival Horror            78  17.98
# 3             Third-Person, Action, Sandbox, Shooter            82  27.13
# 6                 Third-Person, Action, Role-Playing            77  35.55
# 7                              First-Person, Shooter            84  12.18
# 9                  First-Person, Open World, Shooter            83  16.23
# ...                                              ...           ...    ...
# 9114                                          Puzzle            82    NaN
# 9116                                          Action            70    NaN
# 9117                                          Puzzle            80   0.00
# 9119                                          Puzzle            64    NaN
# 9122                                          Arcade             0    NaN
#
#       PlayStation 2  PlayStation 3  PlayStation 4  PlayStation 5  Xbox One  \
# 0               NaN            NaN          19.20          24.98     17.08
# 3               NaN          28.65            NaN            NaN     25.77
# 6               NaN            NaN            NaN            NaN       NaN
# 7              12.5            NaN            NaN            NaN       NaN
# 9               NaN          15.85          15.87          13.80     15.38
# ...             ...            ...            ...            ...       ...
# 9114            NaN            NaN            NaN            NaN       NaN
# 9116            NaN            NaN            NaN            NaN       NaN
# 9117            NaN            NaN            NaN            NaN       NaN
# 9119            NaN            NaN            NaN            NaN       NaN
# 9122            NaN            NaN            NaN            NaN       NaN
#
#       Xbox 360  Xbox Series X/S  Super Nintendo   Wii  Wii U  total_play_time  \
# 0          NaN            17.58             NaN   NaN    NaN            96.82
# 3        29.13            23.98             NaN   NaN    NaN           134.66
# 6          NaN              NaN             NaN   NaN    NaN            35.55
# 7          NaN              NaN             NaN   NaN    NaN            24.68
# 9        15.97            15.02             NaN   NaN    NaN           108.12
# ...        ...              ...             ...   ...    ...              ...
# 9114       NaN              NaN             NaN  0.13    NaN             0.13
# 9116       NaN              NaN             NaN   NaN    NaN             0.00
# 9117       NaN              NaN             NaN   NaN    NaN             0.00
# 9119       NaN              NaN             NaN   NaN    NaN             0.00
# 9122       NaN              NaN             NaN   NaN    NaN             0.00
#
#              Genre
# 0           Action
# 3           Action
# 6     Role-Playing
# 7          Shooter
# 9          Shooter
# ...            ...
# 9114        Puzzle
# 9116        Action
# 9117        Puzzle
# 9119        Puzzle
# 9122        Action
#
# [5227 rows x 18 columns]

# %% [markdown]
# - Selecting and Renaming needed Columns for the Final Dataset

# %%
## For the final dataset, we keep only the required columns — gameName, genre, reviewScore, and playTime.

merged_df_filtered = merged_df_unique[merged_df_unique["total_play_time"] >= 2].copy()
merged_df_filtered.reset_index(drop=True, inplace=True)

merged_df_filtered = merged_df_filtered.rename(
    columns={
        "Name": "gameName",
        "Genre": "genre",
        "Review_score": "reviewScore",
        "total_play_time": "playTime"
    }
)[["gameName", "genre", "reviewScore", "playTime"]]

final_df = merged_df_filtered.sort_values(by="playTime", ascending=False)
final_df
# Out:
#                        gameName         genre  reviewScore  playTime
# 943              World of Tanks       Shooter           72   2365.37
# 2833     Phantasy Star Online 2  Role-Playing           80    730.00
# 652           World of Warcraft  Role-Playing           85    697.23
# 1065                    FIFA 14        Sports           72    623.96
# 135                   Minecraft          Misc           88    586.77
# ...                         ...           ...          ...       ...
# 1023  Mario Kart: Super Circuit        Racing           66      2.00
# 2780                  Anubis II      Platform           15      2.00
# 2974            SingStar Vol. 2          Misc           70      2.00
# 2419    Alvin and the Chipmunks          Misc           45      2.00
# 2708             SingStar Queen          Misc           70      2.00
#
# [3010 rows x 4 columns]

# %% [markdown]
# - save final dataset as csv file

# %%
merged_df_filtered.to_csv(data_path + 'final_hltb.csv')

# %% [markdown]
# ### Task 2

# %% [markdown]
# # ---------------------------------------------------------
# Task 2 aims to conduct data-driven exploration based on our final merged video-game dataset.
# Since the combined dataset includes information such as **game genre, platform, average playtime, and review scores**, we are able to perform cross-dimensional analysis and extract meaningful insights about the gaming industry.
#
# In this section, we focus on the following three core research questions:
#
# 1. **Does game genre influence the average playtime of a game?**
# 2. **Does game genre affect the review scores given by players?**
# 3. **Is there a correlation between game playtime and review score?**
#
# Each question will be presented following the structure below:
# - Clearly state the research question
# - Show the full analytical procedure, including data-processing steps and Python code
# - Provide visualizations or statistical outputs when necessary
# - Conclude with interpretation and discussion of the findings
#
# Through these questions, we aim to demonstrate the value of the merged dataset and show that the results of our data-cleaning and integration workflow can effectively support real analytical tasks and reveal potential relationships between player behaviour and game characteristics.
# # ---------------------------------------------------------

# %% [markdown]
# **Task 2:**
#
# Q1. **Does game genre influence the average playtime of a game?**

# %%
## load needed packages
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
## loading final files (csv)
df = pd.read_csv('dataset/final_hltb.csv')
df.head()
# Out:
#    Unnamed: 0             gameName         genre  reviewScore  playTime
# 0           0          Dying Light        Action           78     96.82
# 1           1  Grand Theft Auto IV        Action           82    134.66
# 2           2          The Witcher  Role-Playing           77     35.55
# 3           3            Half-Life       Shooter           84     24.68
# 4           4            Far Cry 3       Shooter           83    108.12

# %%
# ------------------------------------------------------------
# Figure 1: Average Play Time by Game Genre (Bar Chart)
# ------------------------------------------------------------
plt.figure(figsize=(14,6))
genre_mean = df.groupby('genre')['playTime'].mean().sort_values()
sns.barplot(x=genre_mean.index, y=genre_mean.values)
plt.xticks(rotation=75)
plt.ylabel("Average Play Time (hours)")
plt.title("Average Play Time by Genre")
plt.show()

# %%
# -----------------------------
# Figure 2: Play Time Distribution Across Genres (Box Plot)
# -----------------------------
def plot_playtime_boxplot_zoomed(df, min_sample_size=20, percentile_cutoff=0.95):

    df_clean = df[['genre', 'playTime']].copy()
    df_clean['playTime'] = pd.to_numeric(df_clean['playTime'], errors='coerce')
    df_clean = df_clean.dropna()

    genre_counts = df_clean['genre'].value_counts()
    valid_genres = genre_counts[genre_counts >= min_sample_size].index

    df_filtered = df_clean[df_clean['genre'].isin(valid_genres)]

    cutoff_value = df_filtered['playTime'].quantile(percentile_cutoff)

    df_zoomed = df_filtered[df_filtered['playTime'] <= cutoff_value]

    df_zoomed = df_zoomed.sort_values('genre')

    plt.figure(figsize=(14, 6))
    sns.boxplot(
        data=df_zoomed,
        x="genre",
        y="playTime"
        # palette="Oranges"
    )
    plt.xticks(rotation=75)
    plt.title(f"Play Time Distribution by Genre (Boxplot, Bottom {percentile_cutoff*100:.0f}%)")
    plt.xlabel("Genre")
    plt.ylabel("Play Time (hours)")
    plt.grid(axis="y", linestyle="--", alpha=0.7)
    plt.tight_layout()
    plt.show()

plot_playtime_boxplot_zoomed(df, min_sample_size=20, percentile_cutoff=0.95)

# %% [markdown]
#  **Question 1 Answer:**
#
# *Figure 1. Significant differences in average playtime across game genres*
#
# - **RPG (Role-Playing)**: Longest average playtime, exceeding 70 hours
# - **Sports**: Also relatively long, around 47 hours
# - **Action / Shooter / Simulation**: Mid-range, approximately 25–30 hours
# - **Puzzle / Fighting**: Shortest playtime, generally only 10–15 hours
#
# This shows that there are clear differences in average playtime across different game genres.
#
# ## ---
#
# *Figure 2. RPG and Sports Show the Highest Playtime Variability (Updated Boxplot Analysis)*
#
# From the boxplot (bottom 95% of playtime):
#
# - RPG displays the widest playtime spread, with a large interquartile range and many high-playtime values approaching 100 hours
# - Sports also shows substantial variability, including frequent mid-to-long playtime outliers
# - Racing, Shooter, Simulation, and Action all show moderate spreads, indicating a mix of short and long experiences
# - Puzzle, Fighting, and Misc remain the most compact, with low medians and minimal dispersion
# - Most lower-playtime genres cluster below 20 hours, while RPG and Sports stretch far above that range
#
# This indicates that content-driven genres (like RPG and Sports) tend to offer longer or more replayable experiences, while lighter genres remain short and focused.
#
# ## ---
#
# *3. Overall Conclusion*
#
# Combining both the average playtime and the distribution patterns:
#
# - Genre plays a major role in shaping game playtime
# - RPG and Sports games consistently show both high averages and high variability, suggesting they contain more extensive content, open-world structures, or strong replay value
# - Puzzle, Fighting, and other short-session genres demonstrate shorter and more consistent playtimes, reflecting compact design and quick gameplay loops
# - Several mid-range genres (Action, Shooter, Strategy, Simulation) fall in between, indicating flexible play lengths depending on game design
#
# **Therefore, Game genre has a significant impact on playtime.**

# %% [markdown]
# **Task 2:**
#
# 2. **Does game genre affect the review scores given by players?**

# %%
# -----------------------------
# Figure 1: Average Review Score by Genre (Bar Chart)
# -----------------------------
plt.figure(figsize=(14,6))
genre_review = df.groupby('genre')['reviewScore'].mean().sort_values()
sns.barplot(x=genre_review.index, y=genre_review.values, palette="viridis")
plt.xticks(rotation=75)
plt.ylabel("Average Review Score")
plt.title("Average Review Score by Genre")
plt.show()
# Out:
# /var/folders/zm/15khml3n0hb3_l0rm7qr556r0000gn/T/ipykernel_29552/4266959741.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=genre_review.index, y=genre_review.values, palette="viridis")

# %%
# -----------------------------
# Figure 2: Distribution of Review Scores (Box Plot)
# -----------------------------
plt.figure(figsize=(12, 7))

sns.boxplot(
    x='genre',
    y='reviewScore',
    data=df,
    # palette='Oranges'   
)

plt.title('Score Distribution by Genre', fontsize=16)
plt.ylabel('Score (points)')
plt.xlabel('Genre')

plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Question 2 Answer：**
#
# *Figure 1. There are noticeable differences in average review scores across game genres (though less significant than playtime)*
#
# According to the bar chart:
#
# - **Strategy**, **Role-Playing**, and **Platform** genres have the highest average scores, around **72–75**
# - **Puzzle**, **Racing**, and **Misc** have the lowest average scores, around **63–66**
# - Most genres fall within the **65–72** score range
#
# Overall, there is roughly a 10-point difference between genres, which represents a moderate level of variation.
#
# Game genre does influence review scores, but the effect is weaker compared to its impact on playtime.
#
# # ---
#
# *Figure 2. Score Distribution by Genre (Boxplot Analysis)*
#
# - Most genres have a tight concentration of scores between 65–80, showing that the majority of games, regardless of genre, tend to receive mid-to-high ratings
# - Role-Playing and Strategy genres exhibit higher medians and upper quartiles, indicating that these genres consistently attract stronger player approval
# - Puzzle, Misc, and Racing show lower medians and include a larger number of low-score outliers, suggesting greater inconsistency in quality
# - Outliers appear across every genre, demonstrating that individual game quality varies widely within the same category
# - The substantial overlap of boxes across genres suggests that genre alone cannot fully explain score differences
#
# Overall, while some genres trend higher or lower, the distributions overlap heavily, meaning genre impact is present but limited.
#
# ## ---
#
# *3. Overall Conclusion*
#
# Combining both the average playtime and the distribution patterns:
#
# - Genres show moderate differences in average scores, supported by the bar chart
# - The boxplot reveals that most genres share very similar score ranges, with only small shifts in median and spread
# - Role-Playing and Strategy stand out with slightly higher and more consistent ratings
# - Puzzle, Racing, and Misc have lower medians and more low-score games, indicating less stable player satisfaction
# - However, the large overlap across genres shows that individual game quality matters far more than genre category
#
# **Therefore, based on these findings, Genre does influence review scores to some extent, but the effect is not strong. While some genres tend to perform better on average, player ratings vary widely within each category, showing that genre alone is not a reliable predictor of review score.**

# %% [markdown]
# **Task 2:**
#
# 3. **What’s the relationship between playtime and game ratings?**

# %%
# -----------------------------
# Figure 1: 
# -----------------------------
plt.figure(figsize=(10,6))
sns.regplot(data=df, x="playTime", y="reviewScore", 
            scatter_kws={'alpha':0.8})
plt.xlabel("Play Time (hours)")
plt.ylabel("Review Score")
plt.title("Relationship Between Play Time and Review Score")
plt.ylim(0, 100)   
plt.xlim(0, 200)  
plt.grid(True, linestyle='--', alpha=0.2)
plt.tight_layout()
plt.show()

# %%
# -----------------------------
# Figure 2: 
# -----------------------------
genre_counts = df['genre'].value_counts()
valid_genres = genre_counts[genre_counts >= 20].index
df_filtered = df[df['genre'].isin(valid_genres)]
cutoff_value = df_filtered['playTime'].quantile(0.95)


df_zoomed = df_filtered[df_filtered['playTime'] <= cutoff_value]
g = sns.lmplot(
    data=df,     
    x='playTime',
    y='reviewScore',
    hue='genre',      
    logx=True,       
    height=7,
    aspect=1.5,
    scatter_kws={'alpha':0.3} 
)
title_text = f'Score vs. Average Playtime Correlation (Bottom {0.95*100:.0f}%)'
g.set(
    title=title_text,
    xlabel='Average Playtime (hours) - Log Scale', 
    ylabel='Score (points)'                 
)
plt.xlim(0, 200)  
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
df_clean = df[['genre', 'reviewScore', 'playTime']].dropna()
genre_counts = df_clean['genre'].value_counts()
valid_genres = genre_counts[genre_counts >= 20].index
df_filtered = df_clean[df_clean['genre'].isin(valid_genres)]

results_list = []
for g in valid_genres:
    df_genre = df_clean[df_clean['genre'] == g]
    
    if len(df_genre) < 3:
        continue
        
    rho_s, p_s = stats.spearmanr(df_genre['reviewScore'], df_genre['playTime'])
    rho_p, p_p = stats.pearsonr(df_genre['reviewScore'], df_genre['playTime'])
    
    results_list.append({
        'Genre': g,
        'Spearman_rho (ρ)': rho_s,
        'Spearman_p_value': p_s,
        'Pearson_rho (r)': rho_p,
        'Pearson_p_value': p_p,
        'Sample_Size (n)': len(df_genre)
    })

results_df = pd.DataFrame(results_list)

results_df_sorted = results_df.sort_values(by='Spearman_rho (ρ)', ascending=False)

print("\n" + "="*80)
print("      'Score' vs. 'Meantime' correlation comparasion (Spearman vs Pearson)")
print("="*80)
print(results_df_sorted.to_string(index=False, float_format="%.4f"))
print("="*80)
# Out:
# ================================================================================
#       'Score' vs. 'Meantime' correlation comparasion (Spearman vs Pearson)
# ================================================================================
#        Genre  Spearman_rho (ρ)  Spearman_p_value  Pearson_rho (r)  Pearson_p_value  Sample_Size (n)
#         Misc            0.5805            0.0000           0.2947           0.0019              109
#       Action            0.4784            0.0000           0.3858           0.0000              705
#     Platform            0.4657            0.0000           0.3721           0.0000              264
# Role-Playing            0.4192            0.0000           0.3215           0.0000              377
#    Adventure            0.4051            0.0000           0.3928           0.0000              191
#      Shooter            0.4030            0.0000           0.0859           0.0920              386
#       Racing            0.3880            0.0000           0.2689           0.0001              215
#   Simulation            0.3823            0.0000           0.2506           0.0030              138
#       Sports            0.3253            0.0000           0.1716           0.0104              222
#     Strategy            0.3064            0.0000           0.2054           0.0039              196
#       Puzzle            0.2010            0.1113           0.1642           0.1947               64
#     Fighting            0.0180            0.8309           0.0535           0.5258              143
# ================================================================================

# %% [markdown]
# **Question 3 Answer:**
#
# *Figure 1. Relationship Between Playtime and Review Score (Scatter Plot + Regression Line)*
#
# - After trimming the y-axis to the realistic range (0–100), the scatter points still form a dense horizontal cloud, showing almost no upward trend
# - The regression line is nearly flat, indicating very weak relationship between playtime and score
# - Games with short playtime (0–20 hours) already cover nearly the full score range (0–100)
# - Longer-playtime games (60–150 hours) do not show systematically higher scores – they still cluster around 70–85
#
# Therefore, this suggests that playtime alone does not explain variation in review scores.
# A long game does not guarantee higher player ratings.
#
# # ---
#
# *Figure 2. Genre-Based Playtime–Score Relationship (Bottom 95%, Multiple Regressions)*
#
# - When analyzed by genre, each genre shows a slightly increasing regression line, but the slope is very small
# - The upward trend exists, but it is very weak and inconsistent across genres
# - Different genres overlap heavily: even with long playtime, scores are still widely dispersed
# - Removing extreme outliers (top 5% longest playtime) does not strengthen the relationship
#
# Across genres, the relationship remains weak.
# Playtime has only a minor positive correlation with score, but the effect is not strong enough to be meaningful.
#
# # ---
#
# *Table 1. 'Score' vs. 'Meantime' correlation comparasion*
#
# - Across all genres, both Spearman and Pearson correlations remain weak to moderate, typically ranging between 0.20 and 0.48
# - Genres such as Misc, Action, and Platform show slightly higher Spearman coefficients, suggesting a mild monotonic trend—longer playtime may be loosely associated with higher scores
# - Pearson correlations are consistently lower, indicating that the relationship is far from linear, even in genres where rank-based relationships appear stronger
# - Several genres (e.g., Shooter, Puzzle, Fighting) show very low or non-significant correlations, reinforcing that playtime and score often vary independently
# - The significance of many p-values is largely due to large sample sizes, rather than strong effect sizes
#
# Overall, the correlation table confirms the same pattern observed in the scatter plots and regression lines:
# playtime and score are only weakly related, and the relationship is inconsistent across genres.
#
# # ---
#
# *Overall Conclusion:*
#
# - Both the general scatter plot and the genre-based regressions show the same message:
#      There is no strong relationship between playtime and game ratings.
# - The overall pattern is a weak positive correlation: games with longer playtime may score slightly higher on average
# - However, the effect is extremely small, and score variation is still very large at any playtime level
# - Short games can receive high ratings, and long games can receive mediocre ratings
#
# Playtime is not a significant predictor of game ratings.
# The relationship is weak, inconsistent, and not strong enough to draw meaningful conclusions.

# %% [markdown]
# # --------------------------------------------------
# ### Task 3

# %% [markdown]
# # --------------------------------------------------
# #### **Limitations & Web Scraping Solution**
#
# After merging the **VGSales** and **HLTB** datasets, we obtained information such as
# **playtime, review score, genre, and platform**.
#
# However, we still lack one crucial dimension needed to learn about:
#
# #### **Q4: Verify the validity of ratings**
#
# # ---
#
# #### **Why the existing data cannot answer this question (Limitations)**
#
# #### 🔹 **1. Review scores are only numerical values, without review text**
# - The dataset only contains a numeric score, such as 68, 74, 80
# - It does not reveal *why* players gave this score
# - It cannot reflect what players care about (story? combat? graphics? bugs?)
#
# # ---
#
# #### 🔹 **2. No sentiment information**
# - No labels of “positive / negative feedback”
# - We cannot determine whether highly rated games truly receive positive emotional responses
#
# # ---
#
# #### 🔹 **3. Impossible to analyze keywords and their influence**
#
# We cannot extract:
# - **Positive terms:** excellent, fun, immersive, great story
# - **Negative terms:** boring, buggy, repetitive
#
# Without review text, it is impossible to build a
# **score ↔ review content** relationship model.
#
# # ---
#
# #### 🧩 **Conclusion: Why do we need Web Scraping?**
#
# Because **without review text, we cannot evaluate whether player sentiment truly matches the review score**.
# Therefore, to answer Q4, we must obtain additional review content from external sources.
#
# # ---
#
# #### **⭐ Web Scraping Solution**
#
# To address this missing dimension, we implemented a Python-based web scraper to collect player review text for each game.
#
# Goal: **Collect around 100 real reviews per game (a sufficient sample for sentiment analysis)**
#
# # ---
#
# #### 📌 **Why Web Scraping Is Important**
#
# With scraped review text, we are able to perform:
# - 🔍 **Sentiment Analysis**
# - 🔍 **Keyword Extraction**
# - 🔍 **Evaluation of whether score and sentiment align**
#
# # --------------------------------------------------

# %% [markdown]
# #### Required Install Commands for NLP & Web Scraping
#
# To ensure all required packages are available in the environment, install the following:
#
# ```bash
# pip install requests
# pip install nltk
# pip install wordcloud
# pip install matplotlib

# %%
## load needed packages
import requests
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
from collections import Counter
from nltk.corpus import stopwords
import string
from wordcloud import WordCloud
import matplotlib.pyplot as plt
nltk.download('stopwords')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package stopwords to /Users/leo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/leo/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# - Search Steam AppID by Game Name

# %%
## Search Steam for the game by name and return its Steam AppID (unique identifier)
def search_steam_appid(game_name):

    url = f"https://steamcommunity.com/actions/SearchApps/{game_name}"
    try:
        resp = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
        data = resp.json()

        if len(data) == 0:
            return None  

        # 返回最匹配的一项
        return data[0].get("appid", None)

    except Exception as e:
        print("Error:", e)
        return None

# df["appID"] = df["gameName"].apply(search_steam_appid)     
# df.head()

# %% [markdown]
# - Fetch Steam Reviews Using AppID (Steam Official API)

# %%
## Fetch the latest English reviews from Steam's official appreviews API,
## using a given Steam AppID, and return them as a clean DataFrame.

def fetch_steam_reviews(appid, num=100):

    url = f"https://store.steampowered.com/appreviews/{appid}"
    
    params = {  
        "json": 1,
        "language": "english",
        "filter": "recent",
        "num_per_page": num,
        "cursor": "*"
    }

    resp = requests.get(url, params=params, headers={"User-Agent": "Mozilla/5.0"})
    data = resp.json()
    
    reviews = data.get("reviews", [])
    rows = []
    for r in reviews[:num]:
        rows.append({
            "appid": appid,
            # "recommend": r.get("voted_up"),
            "review_text": r.get("review"),
        })
    return pd.DataFrame(rows)

# %% [markdown]
# - Example: A Single Game Record (Grand Theft Auto IV)

# %%
gta_4 = pd.DataFrame({
    "gameName": ["Grand Theft Auto IV"],
    "genre": ["Action"],
    "reviewScore": [82],
    "playTime": [134.66]
})
gta_4
# Out:
#               gameName   genre  reviewScore  playTime
# 0  Grand Theft Auto IV  Action           82    134.66

# %% [markdown]
# - Search Steam AppID by Game Name & Fetch Reviews (Integrated Function)

# %%
## This function combines two steps:
##    1) Search Steam AppID using the game name
##    2) Fetch reviews using the AppID (from our previous API function)
## 
## In other words:
##    You type a game name → It automatically finds its AppID → 
##    Then downloads the latest `num` reviews and returns them in a DataFrame.
## 
## This is the MOST important integration function in Task 3.

def fetch_reviews_by_name(game_name, num=100):
    appid = search_steam_appid(game_name)

    if appid is None:
        print(f"Unable to find {game_name} 的 AppID")
        return pd.DataFrame()

    print(f"Found the game：{game_name} → AppID = {appid}")

    return fetch_steam_reviews(appid, num=num)

comments_df = fetch_reviews_by_name("Grand Theft Auto IV", 100)
comments_df
# Out:
# Found the game：Grand Theft Auto IV → AppID = 3240220
#       appid                                        review_text
# 0   3240220  grinding online as a solo is such a nightmare,...
# 1   3240220  80+ hours on GTA V Legacy just for my online a...
# 2   3240220  Great story, love Trevor the most. Fuck online...
# 3   3240220                                          it is fun
# 4   3240220                                                  .
# ..      ...                                                ...
# 95  3240220                                                  .
# 96  3240220                                     JOGO BRABO\r\n
# 97  3240220                                     very very cool
# 98  3240220  its good both story and online but i prefered ...
# 99  3240220  I follow big boned people around town as trevo...
#
# [100 rows x 2 columns]

# %% [markdown]
# - Sentiment Analysis using VADER (Classify Each Review as Positive / Negative / Neutral)

# %%
## Use VADER (a rule-based sentiment analysis tool) to compute sentiment scores 
## for each review, and classify them into “positive”, “negative”, or “neutral”.

# Initialize the sentiment analyzer
sia = SentimentIntensityAnalyzer()

def get_sentiment_score_vader(text):
    if not isinstance(text, str) or not text.strip():
        return 0.0  
     # 'compound' ranges from [-1, 1], higher = more positive
    return sia.polarity_scores(text)['compound']

def label_sentiment(score, pos_th=0.05, neg_th=-0.05):
    if score >= pos_th:
        return "positive"
    elif score <= neg_th:
        return "negative"
    else:
        return "neutral"

# Compute the original VADER sentiment score in the range of [-1, 1].
comments_df["sentiment_score"] = comments_df["review_text"].apply(get_sentiment_score_vader)

# Scale the scores to the [0,1] range 
# (for easier aggregation and interpretation) 
# by creating a new column without overwriting the original values.
comments_df["sentiment_score_scaled"] = (comments_df["sentiment_score"] + 1) / 2

# label by sentiment
comments_df["sentiment_label"] = comments_df["sentiment_score"].apply(label_sentiment)

comments_df.head()
# Out:
#      appid                                        review_text  \
# 0  3240220  grinding online as a solo is such a nightmare,...
# 1  3240220  80+ hours on GTA V Legacy just for my online a...
# 2  3240220  Great story, love Trevor the most. Fuck online...
# 3  3240220                                          it is fun
# 4  3240220                                                  .
#
#    sentiment_score  sentiment_score_scaled sentiment_label
# 0          -0.6207                 0.18965        negative
# 1           0.7050                 0.85250        positive
# 2           0.6712                 0.83560        positive
# 3           0.5106                 0.75530        positive
# 4           0.0000                 0.50000         neutral

# %% [markdown]
# - Summarize Sentiment Results (Count, Sentiment_Score, Scaled_Sentiment_Score, Sentiment_Percentage)

# %%
total_scaled = comments_df["sentiment_score_scaled"].sum()
print("Total scaled sentiment score:", float(total_scaled))

## Group all reviews by sentiment category (positive / neutral / negative)
## and compute: count, percentage, average sentiment score (raw & scaled).

summary_df = comments_df.groupby("sentiment_label").agg(
    count=("sentiment_label", "size"),
    avg_sentiment_raw=("sentiment_score", "mean"),           
    avg_sentiment_scaled=("sentiment_score_scaled", "mean"), 
).reset_index()

# Percentage share of each category
summary_df["percentage"] = (summary_df["count"] / summary_df["count"].sum()).round(2)

# Convert the mean value from the [0,1] range to a 0–100 scale
summary_df["avg_sentiment_percent"] = (summary_df["avg_sentiment_scaled"] * 100).round(2)

summary_df
# Out:
# Total scaled sentiment score: 58.0017
#   sentiment_label  count  avg_sentiment_raw  avg_sentiment_scaled  percentage  \
# 0        negative     20          -0.519360              0.240320         0.2
# 1         neutral     30           0.000337              0.500168         0.3
# 2        positive     50           0.527610              0.763805         0.5
#
#    avg_sentiment_percent
# 0                  24.03
# 1                  50.02
# 2                  76.38

# %% [markdown]
# - Combine All Positive and Negative Reviews into Two Large Strings

# %%
## Join all positive reviews and negative reviews separately
## Convert to strings to avoid type issues before concatenation.
positive_text = " ".join(comments_df[comments_df["sentiment_label"] == "positive"]["review_text"].astype(str))
negative_text = " ".join(comments_df[comments_df["sentiment_label"] == "negative"]["review_text"].astype(str))

# %% [markdown]
# - Clean Review Text: Lowercase, Remove Special Characters, Remove Stopwords (To make the word cloud cleaner and more meaningful)

# %%
# Base English stopwords
stop_words = set(stopwords.words("english"))


## Custom stopwords (words you do NOT want to appear in the word clouds)
## These include: common gaming terms + filler words + noise words
custom_stopwords = {
    "game", "games", "play", "played", "playing",   
    "u", "im", "ive", "feel", "even", "ever", "much",
    "many", "still", "feels", "get", "lot", "every",
    "year", "years", "really", "online", "gta", "time",
    "dont", "cant", "enhanced", "youre", "thing", "also",
    "must"                       
}

# Merge
stop_words = stop_words.union(custom_stopwords)

def clean_text(text):
    text = text.lower()  
    text = re.sub(r"[^a-z\s]", "", text) 
    words = [w for w in text.split() if w not in stop_words and len(w) > 2]
    return " ".join(words)

# %% [markdown]
# - Clean Positive & Negative Review Text Separately ((lowercasing, removing punctuation, removing stopwords))

# %%
positive_clean = clean_text(positive_text) # Clean all positive review text
negative_clean = clean_text(negative_text) # Clean all negative review text

# %% [markdown]
# - Generate Word Clouds for Positive/Negative Reviews

# %%
"""
Generate a word cloud for the input text.
Automatically applies different styles for positive vs. negative sentiment.

"""
def generate_wordcloud(text, sentiment="positive"):

    if sentiment.lower() == "positive":
        wc = WordCloud(
            width=800,
            height=400,
            background_color="white"
        ).generate(text)

        title = "Positive Review Keywords"
        title_color = "black"

    else:
        wc = WordCloud(
            width=800,
            height=400,
            background_color="black",
            colormap="Reds"
        ).generate(text)

        title = "Negative Review Keywords"
        title_color = "black"

    # ---- Plot ----
    plt.figure(figsize=(10,5))
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(title, fontsize=18, color=title_color)
    plt.show()


generate_wordcloud(positive_clean, sentiment="positive")
generate_wordcloud(negative_clean, sentiment="negative")

# %% [markdown]
# - Top Word Frequency (Positive vs Negative Reviews - top 20)

# %%
# 1. Prepare stopwords + custom filtering rules
def clean_and_tokenise(text):
    if not text:
        return []
    tokens = []
    for w in text.split():
        w = w.lower().strip(string.punctuation)

        if (w 
            and w not in stop_words
            and not w.isdigit() 
            and len(w) > 2):
            tokens.append(w)
    return tokens

# 2. Clean & tokenize positive/negative review text
pos_tokens = clean_and_tokenise(positive_clean)
neg_tokens = clean_and_tokenise(negative_clean)

# Count top 20 words
pos_words = Counter(pos_tokens).most_common(20)
neg_words = Counter(neg_tokens).most_common(20)



# 3. Plot Top 20 Positive Words
pd.DataFrame(pos_words, columns=["word","count"]).plot(
    kind="bar", x="word", legend=False, figsize=(10,5)
)
plt.title("Top 20 Positive Words (Cleaned)")
plt.xlabel("Word")
plt.ylabel("Count")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# 4. Plot Top 20 Negative Words
pd.DataFrame(neg_words, columns=["word","count"]).plot(
    kind="bar", x="word", color="red", legend=False, figsize=(10,5)
)
plt.title("Top 20 Negative Words (Cleaned)")
plt.xlabel("Word")
plt.ylabel("Count")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
